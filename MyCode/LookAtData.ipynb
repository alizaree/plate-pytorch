# %%
import sys
 
# setting path
sys.path.append('../')
import argparse
import os
import shutil
import time
import numpy as np
import matplotlib.pyplot as plt
from collections import OrderedDict
import torch
import torch.backends.cudnn as cudnn
#from callbacks import AverageMeter, Logger
from data_utils.data_loader_frames_new import VideoFolder
from utils import save_results
import torchvision
import ffmpeg
from model.model_lib_new import BC_MODEL as VideoModel

# %%
class creat_args():
    def __init__(self,root):
        self.root_frames=root
root='/dvmm-filer3a/users/yulei/data/crosstask/'
args=creat_args(root)
if args.root_frames=='':
        args.root_frames = '/dvmm-filer3a/users/yulei/data/crosstask/'       
args.max_traj_len =None
args.num_classes = 133  # max_n_step = 11, sum 133
args.model_type = 'woT'  # 'model_T'
args.num_frames = 8
args.model = 'global_gpt'
args.json_data_train=''
args.json_file_labels=''
args.max_sentence_len=3
args.dataset='crosstask'
args.NumActionSteps=None
args.batch_size=1
args.NumFramesAroundState=5

# %%
dataset_train = VideoFolder(root=args.root_frames,
                                file_input=args.json_data_train,
                                file_labels=args.json_file_labels,
                                frames_duration=args.num_frames,
                                args=args,
                                is_val=False,
                                if_augment=True,
                                model=args.model,
                                max_sentence_length=args.max_sentence_len,
                                max_traj_len=args.max_traj_len,
                                NumActionSteps=args.NumActionSteps,
                                NumFramesAroundState=args.NumFramesAroundState
                                )



# create training and validation loader
train_loader = torch.utils.data.DataLoader(
    dataset_train,
    batch_size=args.batch_size, shuffle=True,
    pin_memory=True
)
# Out:
# self.max_traj_len:  None
# /dvmm-filer2/users/ali/purcedure_planing/Code/plate-pytorch/MyCode/../data_utils/data_loader_frames_new.py:240: UserWarning: Skipping missing video: Nxok_XFt3es
#   warnings.warn("Skipping missing video: "+ str(vid))
# /dvmm-filer2/users/ali/purcedure_planing/Code/plate-pytorch/MyCode/../data_utils/data_loader_frames_new.py:240: UserWarning: Skipping missing video: EivBPahDshc
#   warnings.warn("Skipping missing video: "+ str(vid))
# /dvmm-filer2/users/ali/purcedure_planing/Code/plate-pytorch/MyCode/../data_utils/data_loader_frames_new.py:240: UserWarning: Skipping missing video: sIA-JrFjXdM
#   warnings.warn("Skipping missing video: "+ str(vid))
# /dvmm-filer2/users/ali/purcedure_planing/Code/plate-pytorch/MyCode/../data_utils/data_loader_frames_new.py:240: UserWarning: Skipping missing video: DBqsbfsAjxo
#   warnings.warn("Skipping missing video: "+ str(vid))
# /dvmm-filer2/users/ali/purcedure_planing/Code/plate-pytorch/MyCode/../data_utils/data_loader_frames_new.py:240: UserWarning: Skipping missing video: 1Y9Kg9N7nXQ
#   warnings.warn("Skipping missing video: "+ str(vid))
# /dvmm-filer2/users/ali/purcedure_planing/Code/plate-pytorch/MyCode/../data_utils/data_loader_frames_new.py:240: UserWarning: Skipping missing video: 29dN4svdg5Y
#   warnings.warn("Skipping missing video: "+ str(vid))
# /dvmm-filer2/users/ali/purcedure_planing/Code/plate-pytorch/MyCode/../data_utils/data_loader_frames_new.py:240: UserWarning: Skipping missing video: C7cZAOVhexc
#   warnings.warn("Skipping missing video: "+ str(vid))
# /dvmm-filer2/users/ali/purcedure_planing/Code/plate-pytorch/MyCode/../data_utils/data_loader_frames_new.py:240: UserWarning: Skipping missing video: VGv8sV9tXJo
#   warnings.warn("Skipping missing video: "+ str(vid))
# /dvmm-filer2/users/ali/purcedure_planing/Code/plate-pytorch/MyCode/../data_utils/data_loader_frames_new.py:240: UserWarning: Skipping missing video: oEesRZgMx6Q
#   warnings.warn("Skipping missing video: "+ str(vid))
# /dvmm-filer2/users/ali/purcedure_planing/Code/plate-pytorch/MyCode/../data_utils/data_loader_frames_new.py:240: UserWarning: Skipping missing video: gnGnesrdTHQ
#   warnings.warn("Skipping missing video: "+ str(vid))
# /dvmm-filer2/users/ali/purcedure_planing/Code/plate-pytorch/MyCode/../data_utils/data_loader_frames_new.py:240: UserWarning: Skipping missing video: 6Bybi0OsxaM
#   warnings.warn("Skipping missing video: "+ str(vid))
# /dvmm-filer2/users/ali/purcedure_planing/Code/plate-pytorch/MyCode/../data_utils/data_loader_frames_new.py:240: UserWarning: Skipping missing video: pZgn9e-rL6E
#   warnings.warn("Skipping missing video: "+ str(vid))
# /dvmm-filer2/users/ali/purcedure_planing/Code/plate-pytorch/MyCode/../data_utils/data_loader_frames_new.py:240: UserWarning: Skipping missing video: oZER8W-lwZo
#   warnings.warn("Skipping missing video: "+ str(vid))
# /dvmm-filer2/users/ali/purcedure_planing/Code/plate-pytorch/MyCode/../data_utils/data_loader_frames_new.py:240: UserWarning: Skipping missing video: Aq3G8rLJxBQ
#   warnings.warn("Skipping missing video: "+ str(vid))
# /dvmm-filer2/users/ali/purcedure_planing/Code/plate-pytorch/MyCode/../data_utils/data_loader_frames_new.py:240: UserWarning: Skipping missing video: bE3aH7J0_z8
#   warnings.warn("Skipping missing video: "+ str(vid))
# /dvmm-filer2/users/ali/purcedure_planing/Code/plate-pytorch/MyCode/../data_utils/data_loader_frames_new.py:240: UserWarning: Skipping missing video: fU46OZft_BQ
#   warnings.warn("Skipping missing video: "+ str(vid))
# /dvmm-filer2/users/ali/purcedure_planing/Code/plate-pytorch/MyCode/../data_utils/data_loader_frames_new.py:240: UserWarning: Skipping missing video: VY_BjieXWto
#   warnings.warn("Skipping missing video: "+ str(vid))
# /dvmm-filer2/users/ali/purcedure_planing/Code/plate-pytorch/MyCode/../data_utils/data_loader_frames_new.py:240: UserWarning: Skipping missing video: SNcsgQFUXAQ
#   warnings.warn("Skipping missing video: "+ str(vid))
# /dvmm-filer2/users/ali/purcedure_planing/Code/plate-pytorch/MyCode/../data_utils/data_loader_frames_new.py:240: UserWarning: Skipping missing video: VAAFphtxUNc
#   warnings.warn("Skipping missing video: "+ str(vid))
# /dvmm-filer2/users/ali/purcedure_planing/Code/plate-pytorch/MyCode/../data_utils/data_loader_frames_new.py:240: UserWarning: Skipping missing video: ylRpEJ5CKik
#   warnings.warn("Skipping missing video: "+ str(vid))
# /dvmm-filer2/users/ali/purcedure_planing/Code/plate-pytorch/MyCode/../data_utils/data_loader_frames_new.py:240: UserWarning: Skipping missing video: Oy9LroX_RpI
#   warnings.warn("Skipping missing video: "+ str(vid))
# /dvmm-filer2/users/ali/purcedure_planing/Code/plate-pytorch/MyCode/../data_utils/data_loader_frames_new.py:240: UserWarning: Skipping missing video: moEx5N7rYvM
#   warnings.warn("Skipping missing video: "+ str(vid))
# /dvmm-filer2/users/ali/purcedure_planing/Code/plate-pytorch/MyCode/../data_utils/data_loader_frames_new.py:240: UserWarning: Skipping missing video: VSWOyOyykIg
#   warnings.warn("Skipping missing video: "+ str(vid))
# /dvmm-filer2/users/ali/purcedure_planing/Code/plate-pytorch/MyCode/../data_utils/data_loader_frames_new.py:240: UserWarning: Skipping missing video: VJOE9rDhC6E
#   warnings.warn("Skipping missing video: "+ str(vid))
# /dvmm-filer2/users/ali/purcedure_planing/Code/plate-pytorch/MyCode/../data_utils/data_loader_frames_new.py:240: UserWarning: Skipping missing video: 0jFBeaJZwVw
#   warnings.warn("Skipping missing video: "+ str(vid))
# /dvmm-filer2/users/ali/purcedure_planing/Code/plate-pytorch/MyCode/../data_utils/data_loader_frames_new.py:240: UserWarning: Skipping missing video: x2ZN8cW7WKQ
#   warnings.warn("Skipping missing video: "+ str(vid))
# /dvmm-filer2/users/ali/purcedure_planing/Code/plate-pytorch/MyCode/../data_utils/data_loader_frames_new.py:240: UserWarning: Skipping missing video: Jlr0uRh9Cdg
#   warnings.warn("Skipping missing video: "+ str(vid))
# /dvmm-filer2/users/ali/purcedure_planing/Code/plate-pytorch/MyCode/../data_utils/data_loader_frames_new.py:240: UserWarning: Skipping missing video: 7A11hlHTrh0
#   warnings.warn("Skipping missing video: "+ str(vid))
# /dvmm-filer2/users/ali/purcedure_planing/Code/plate-pytorch/MyCode/../data_utils/data_loader_frames_new.py:240: UserWarning: Skipping missing video: 57UXyDlTGdc
#   warnings.warn("Skipping missing video: "+ str(vid))
# /dvmm-filer2/users/ali/purcedure_planing/Code/plate-pytorch/MyCode/../data_utils/data_loader_frames_new.py:240: UserWarning: Skipping missing video: ma5V79URf0Y
#   warnings.warn("Skipping missing video: "+ str(vid))
# /dvmm-filer2/users/ali/purcedure_planing/Code/plate-pytorch/MyCode/../data_utils/data_loader_frames_new.py:240: UserWarning: Skipping missing video: p1nQLpIioI0
#   warnings.warn("Skipping missing video: "+ str(vid))
# /dvmm-filer2/users/ali/purcedure_planing/Code/plate-pytorch/MyCode/../data_utils/data_loader_frames_new.py:240: UserWarning: Skipping missing video: aik2x6p4JLw
#   warnings.warn("Skipping missing video: "+ str(vid))
# /dvmm-filer2/users/ali/purcedure_planing/Code/plate-pytorch/MyCode/../data_utils/data_loader_frames_new.py:240: UserWarning: Skipping missing video: fbLR_b3tFC0
#   warnings.warn("Skipping missing video: "+ str(vid))
# /dvmm-filer2/users/ali/purcedure_planing/Code/plate-pytorch/MyCode/../data_utils/data_loader_frames_new.py:240: UserWarning: Skipping missing video: Vzq2iz_v-z4
#   warnings.warn("Skipping missing video: "+ str(vid))
# /dvmm-filer2/users/ali/purcedure_planing/Code/plate-pytorch/MyCode/../data_utils/data_loader_frames_new.py:240: UserWarning: Skipping missing video: LLKNdpfEy0M
#   warnings.warn("Skipping missing video: "+ str(vid))
# /dvmm-filer2/users/ali/purcedure_planing/Code/plate-pytorch/MyCode/../data_utils/data_loader_frames_new.py:240: UserWarning: Skipping missing video: E7b3pxiLWJg
#   warnings.warn("Skipping missing video: "+ str(vid))
# /dvmm-filer2/users/ali/purcedure_planing/Code/plate-pytorch/MyCode/../data_utils/data_loader_frames_new.py:240: UserWarning: Skipping missing video: bUftQkVcdIQ
#   warnings.warn("Skipping missing video: "+ str(vid))
# /dvmm-filer2/users/ali/purcedure_planing/Code/plate-pytorch/MyCode/../data_utils/data_loader_frames_new.py:240: UserWarning: Skipping missing video: DKySYRxgQHs
#   warnings.warn("Skipping missing video: "+ str(vid))
# /dvmm-filer2/users/ali/purcedure_planing/Code/plate-pytorch/MyCode/../data_utils/data_loader_frames_new.py:240: UserWarning: Skipping missing video: vSjMRLVKgPE
#   warnings.warn("Skipping missing video: "+ str(vid))
# /dvmm-filer2/users/ali/purcedure_planing/Code/plate-pytorch/MyCode/../data_utils/data_loader_frames_new.py:240: UserWarning: Skipping missing video: oDYI2Jf_F28
#   warnings.warn("Skipping missing video: "+ str(vid))
# /dvmm-filer2/users/ali/purcedure_planing/Code/plate-pytorch/MyCode/../data_utils/data_loader_frames_new.py:240: UserWarning: Skipping missing video: GpXQ85E20WA
#   warnings.warn("Skipping missing video: "+ str(vid))
# /dvmm-filer2/users/ali/purcedure_planing/Code/plate-pytorch/MyCode/../data_utils/data_loader_frames_new.py:240: UserWarning: Skipping missing video: 8rMl8CTbgfU
#   warnings.warn("Skipping missing video: "+ str(vid))
# /dvmm-filer2/users/ali/purcedure_planing/Code/plate-pytorch/MyCode/../data_utils/data_loader_frames_new.py:240: UserWarning: Skipping missing video: 4ArD8IM-b-Q
#   warnings.warn("Skipping missing video: "+ str(vid))
# /dvmm-filer2/users/ali/purcedure_planing/Code/plate-pytorch/MyCode/../data_utils/data_loader_frames_new.py:240: UserWarning: Skipping missing video: GNJfDOoVORM
#   warnings.warn("Skipping missing video: "+ str(vid))
# /dvmm-filer2/users/ali/purcedure_planing/Code/plate-pytorch/MyCode/../data_utils/data_loader_frames_new.py:240: UserWarning: Skipping missing video: 7Z_Nb38CvLA
#   warnings.warn("Skipping missing video: "+ str(vid))
# /dvmm-filer2/users/ali/purcedure_planing/Code/plate-pytorch/MyCode/../data_utils/data_loader_frames_new.py:240: UserWarning: Skipping missing video: 3Q2lhktArIc
#   warnings.warn("Skipping missing video: "+ str(vid))
# /dvmm-filer2/users/ali/purcedure_planing/Code/plate-pytorch/MyCode/../data_utils/data_loader_frames_new.py:240: UserWarning: Skipping missing video: k9LkgY6iEEU
#   warnings.warn("Skipping missing video: "+ str(vid))
# /dvmm-filer2/users/ali/purcedure_planing/Code/plate-pytorch/MyCode/../data_utils/data_loader_frames_new.py:240: UserWarning: Skipping missing video: 72RTYY1a7z4
#   warnings.warn("Skipping missing video: "+ str(vid))
# /dvmm-filer2/users/ali/purcedure_planing/Code/plate-pytorch/MyCode/../data_utils/data_loader_frames_new.py:240: UserWarning: Skipping missing video: JHGkSS_paIw
#   warnings.warn("Skipping missing video: "+ str(vid))
# /dvmm-filer2/users/ali/purcedure_planing/Code/plate-pytorch/MyCode/../data_utils/data_loader_frames_new.py:240: UserWarning: Skipping missing video: CkKGbFaE0NA
#   warnings.warn("Skipping missing video: "+ str(vid))
# Number of missing videos 50
# All primary task videos: 2340
# Save to cross_task_data_False.json
# Loading label strings
# ... Loading box annotations might take a minute ...
# length of step data: 2340

# %%
for batch in train_loader:
    data=batch
    break
# Out:
# ffmpeg version 9c33b2f Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/dvmm-filer2/users/ali/anaconda3/envs/envVatt --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/dvmm-filer3a/users/yulei/data/crosstask/crosstask_videos/videos/zxEHm5WkuVc.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2021-01-29T13:47:02.000000Z
#   Duration: 00:08:50.25, start: 0.000000, bitrate: 616 kb/s
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 640x360 [SAR 1:1 DAR 16:9], 484 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2021-01-29T13:47:02.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 01/29/2021.
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       creation_time   : 2021-01-29T13:47:02.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 01/29/2021.
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> rawvideo (native))
# Press [q] to stop, [?] for help
# Output #0, rawvideo, to 'pipe:':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf58.45.100
#     Stream #0:0(und): Video: rawvideo (RGB[24] / 0x18424752), rgb24, 640x360 [SAR 1:1 DAR 16:9], q=2-31, 5529 kb/s, 1 fps, 1 tbn, 1 tbc (default)
#     Metadata:
#       creation_time   : 2021-01-29T13:47:02.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 01/29/2021.
#       encoder         : Lavc58.91.100 rawvideo
# frame=  532 fps=119 q=-0.0 Lsize=  359100kB time=00:08:52.00 bitrate=5529.6kbits/s dup=0 drop=15359 speed= 119x
# video:359100kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%
# /dvmm-filer2/users/ali/purcedure_planing/Code/plate-pytorch/MyCode/../data_utils/data_loader_frames_new.py:392: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:210.)
#   frames_start=torch.tensor(images_start)

# %%
print(data[0].shape,data[1].shape , data[2], data[3].shape)
fig,axes=plt.subplots(2,5,figsize=(10,5))
act=1
for i in range(args.NumFramesAroundState):

    axes[0,i].imshow(data[3][0,act, i,:,:,:])
    #.subplot(2,5,i+1+5)
    axes[1,i].imshow(data[4][0,act, i,:,:,:])
fig.suptitle(data[2][act][0])
# Out:
# torch.Size([1, 531, 360, 640, 3]) torch.Size([1, 8, 1]) [[['season steak']], [['put steak on grill']], [['flip steak']], [['take steak from grill']], [['cut steak']], [['taste steak']], [['cut steak']], [['taste steak']]] torch.Size([1, 8, 5, 360, 640, 3])
# Text(0.5, 0.98, "['put steak on grill']")

# %% [markdown]
# # Now we implement drop_dtw on Clip embeddings to see if the results are simillar

# %%
from PIL import Image
import requests

from transformers import CLIPProcessor, CLIPModel

model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32")
processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")

images=[data[0][0,idd,:,:,:] for idd in range(data[0].shape[1]) ]
texts=[idd[0][0] for idd in data[2]]
inputs = processor( text=texts ,images=images, return_tensors="pt", padding=True)
outputs = model(**inputs)
logits_per_image = outputs.logits_per_image  # this is the image-text similarity score
probs = logits_per_image.softmax(dim=1)  # we can take the softmax to get the label probabilities

# %%
import seaborn as sns
print(probs.shape)


ax = sns.heatmap(probs.detach().numpy().T)
plt.show()
# Out:
# torch.Size([531, 8])

# %%
from Drop_DTW.models.visualization import visualize_drop_dtw_matching_new

def sample_to_device(sample, device):
    for k, v in sample.items():
        try: 
            sample[k] = v.to(device)
        except:
            pass
    return sample


args.drop_cost='logit'
args.dtw_xz_gamma=10
args.keep_percentile=0.3
sample = {}
nFigs=10
idd=0
for batch in train_loader:
    idd+=1
    data=batch
    images=[data[0][0,idd,:,:,:] for idd in range(data[0].shape[1]) ]
    texts=[idd[0][0] for idd in data[2]]
    inputs = processor( text=texts ,images=images, return_tensors="pt", padding=True)
    outputs = model(**inputs)
    logits_per_image = outputs.logits_per_image  # this is the image-text similarity score
    probs = logits_per_image.softmax(dim=1)  # we can take the softmax to get the label probabilities
    sample['frame_features'] = outputs['image_embeds']
    sample['step_features'] = outputs['text_embeds']
    sample['step_ids']=torch.tensor(range(sample['step_features'].shape[0]))
    sample['step_starts']=torch.tensor(data[-1])[:,0]
    sample['step_ends']=torch.tensor(data[-1])[:,1]

    if args.drop_cost == 'learn':
        distractor = None #pl_module.model.compute_distractors(sample['step_features'].mean(0)).detach().cpu()
    else:
        distractor = None

    sample_gammas = args.dtw_xz_gamma
    sample_dict =[sample]# {'Ours': sample_to_device(sample, 'cpu'),'HowTo100M': sample_to_device(sample, 'cpu')}

    dtw_image, frame_labels, gt_labels = visualize_drop_dtw_matching_new(
        sample_dict, distractor, gamma_f=sample_gammas,
        drop_cost=args.drop_cost, keep_percentile=args.keep_percentile, shape=(10, 2))
    if idd>=nFigs:
        break
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# ffmpeg version 9c33b2f Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/dvmm-filer2/users/ali/anaconda3/envs/envVatt --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/dvmm-filer3a/users/yulei/data/crosstask/crosstask_videos/videos/NV9b67H3gyQ.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2019-09-28T08:42:09.000000Z
#   Duration: 00:08:28.56, start: 0.000000, bitrate: 545 kb/s
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 640x360 [SAR 1:1 DAR 16:9], 414 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       creation_time   : 2019-09-28T08:42:09.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 09/28/2019.
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2019-09-28T08:42:09.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 09/28/2019.
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> rawvideo (native))
# Press [q] to stop, [?] for help
# Output #0, rawvideo, to 'pipe:':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf58.45.100
#     Stream #0:0(und): Video: rawvideo (RGB[24] / 0x18424752), rgb24, 640x360 [SAR 1:1 DAR 16:9], q=2-31, 5529 kb/s, 1 fps, 1 tbn, 1 tbc (default)
#     Metadata:
#       creation_time   : 2019-09-28T08:42:09.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 09/28/2019.
#       encoder         : Lavc58.91.100 rawvideo
# frame=  510 fps=144 q=-0.0 Lsize=  344250kB time=00:08:30.00 bitrate=5529.6kbits/s dup=0 drop=11683 speed= 144x
# video:344250kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# ffmpeg version 9c33b2f Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/dvmm-filer2/users/ali/anaconda3/envs/envVatt --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/dvmm-filer3a/users/yulei/data/crosstask/crosstask_videos/videos/aKUidVeIZ3Y.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2015-07-30T10:55:41.000000Z
#   Duration: 00:04:23.71, start: 0.000000, bitrate: 588 kb/s
#     Stream #0:0(und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p, 640x360 [SAR 1:1 DAR 16:9], 490 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 59.94 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 96 kb/s (default)
#     Metadata:
#       creation_time   : 2015-07-30T10:55:44.000000Z
#       handler_name    : IsoMedia File Produced by Google, 5-11-2011
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> rawvideo (native))
# Press [q] to stop, [?] for help
# Output #0, rawvideo, to 'pipe:':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf58.45.100
#     Stream #0:0(und): Video: rawvideo (RGB[24] / 0x18424752), rgb24, 640x360 [SAR 1:1 DAR 16:9], q=2-31, 5529 kb/s, 1 fps, 1 tbn, 1 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.91.100 rawvideo
# frame=  265 fps=123 q=-0.0 Lsize=  178875kB time=00:04:25.00 bitrate=5529.6kbits/s dup=0 drop=7636 speed= 123x
# video:178875kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# ffmpeg version 9c33b2f Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/dvmm-filer2/users/ali/anaconda3/envs/envVatt --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/dvmm-filer3a/users/yulei/data/crosstask/crosstask_videos/videos/KH51fqKmM-Y.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2019-12-02T02:14:12.000000Z
#   Duration: 00:05:44.49, start: 0.000000, bitrate: 566 kb/s
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 640x360 [SAR 1:1 DAR 16:9], 435 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2019-12-02T02:14:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/01/2019.
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2019-12-02T02:14:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/01/2019.
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> rawvideo (native))
# Press [q] to stop, [?] for help
# Output #0, rawvideo, to 'pipe:':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf58.45.100
#     Stream #0:0(und): Video: rawvideo (RGB[24] / 0x18424752), rgb24, 640x360 [SAR 1:1 DAR 16:9], q=2-31, 5529 kb/s, 1 fps, 1 tbn, 1 tbc (default)
#     Metadata:
#       creation_time   : 2019-12-02T02:14:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/01/2019.
#       encoder         : Lavc58.91.100 rawvideo
# frame=  346 fps=113 q=-0.0 Lsize=  233550kB time=00:05:46.00 bitrate=5529.6kbits/s dup=0 drop=9978 speed= 113x
# video:233550kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# ffmpeg version 9c33b2f Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/dvmm-filer2/users/ali/anaconda3/envs/envVatt --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/dvmm-filer3a/users/yulei/data/crosstask/crosstask_videos/missing_videos/SXGB0nfWSc8.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2016-08-14T11:12:21.000000Z
#   Duration: 00:05:30.88, start: 0.000000, bitrate: 2132 kb/s
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p, 1280x720 [SAR 1:1 DAR 16:9], 2003 kb/s, 25 fps, 25 tbr, 90k tbn, 50 tbc (default)
#     Metadata:
#       creation_time   : 2016-08-14T11:12:21.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 125 kb/s (default)
#     Metadata:
#       creation_time   : 2016-08-14T11:12:21.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> rawvideo (native))
# Press [q] to stop, [?] for help
# Output #0, rawvideo, to 'pipe:':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf58.45.100
#     Stream #0:0(und): Video: rawvideo (RGB[24] / 0x18424752), rgb24, 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 22118 kb/s, 1 fps, 1 tbn, 1 tbc (default)
#     Metadata:
#       creation_time   : 2016-08-14T11:12:21.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
#       encoder         : Lavc58.91.100 rawvideo
# frame=  332 fps= 41 q=-0.0 Lsize=  896400kB time=00:05:32.00 bitrate=22118.4kbits/s dup=0 drop=7940 speed=41.2x
# video:896400kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# ffmpeg version 9c33b2f Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/dvmm-filer2/users/ali/anaconda3/envs/envVatt --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/dvmm-filer3a/users/yulei/data/crosstask/crosstask_videos/videos/0vD--H7poxU.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2018-09-22T20:25:44.000000Z
#   Duration: 00:09:10.71, start: 0.000000, bitrate: 567 kb/s
#     Stream #0:0(und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(tv, bt709), 640x360 [SAR 1:1 DAR 16:9], 469 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2018-09-22T20:25:44.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 09/22/2018.
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 96 kb/s (default)
#     Metadata:
#       creation_time   : 2018-09-22T20:25:44.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 09/22/2018.
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> rawvideo (native))
# Press [q] to stop, [?] for help
# Output #0, rawvideo, to 'pipe:':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf58.45.100
#     Stream #0:0(und): Video: rawvideo (RGB[24] / 0x18424752), rgb24, 640x360 [SAR 1:1 DAR 16:9], q=2-31, 5529 kb/s, 1 fps, 1 tbn, 1 tbc (default)
#     Metadata:
#       creation_time   : 2018-09-22T20:25:44.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 09/22/2018.
#       encoder         : Lavc58.91.100 rawvideo
# frame=  552 fps=130 q=-0.0 Lsize=  372600kB time=00:09:12.00 bitrate=5529.6kbits/s dup=0 drop=15951 speed= 130x
# video:372600kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# ffmpeg version 9c33b2f Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/dvmm-filer2/users/ali/anaconda3/envs/envVatt --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/dvmm-filer3a/users/yulei/data/crosstask/crosstask_videos/videos/AtBFvCwEPTc.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2018-11-13T02:35:08.000000Z
#   Duration: 00:06:48.46, start: 0.000000, bitrate: 546 kb/s
#     Stream #0:0(und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(tv, bt709), 640x360 [SAR 1:1 DAR 16:9], 447 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       creation_time   : 2018-11-13T02:35:08.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/12/2018.
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 95 kb/s (default)
#     Metadata:
#       creation_time   : 2018-11-13T02:35:08.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/12/2018.
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> rawvideo (native))
# Press [q] to stop, [?] for help
# Output #0, rawvideo, to 'pipe:':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf58.45.100
#     Stream #0:0(und): Video: rawvideo (RGB[24] / 0x18424752), rgb24, 640x360 [SAR 1:1 DAR 16:9], q=2-31, 5529 kb/s, 1 fps, 1 tbn, 1 tbc (default)
#     Metadata:
#       creation_time   : 2018-11-13T02:35:08.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/12/2018.
#       encoder         : Lavc58.91.100 rawvideo
# frame=  410 fps=156 q=-0.0 Lsize=  276750kB time=00:06:50.00 bitrate=5529.6kbits/s dup=0 drop=9382 speed= 156x
# video:276750kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# ffmpeg version 9c33b2f Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/dvmm-filer2/users/ali/anaconda3/envs/envVatt --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/dvmm-filer3a/users/yulei/data/crosstask/crosstask_videos/videos/6g_k3QW9Icc.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2016-02-08T02:42:02.000000Z
#   Duration: 00:02:09.61, start: 0.000000, bitrate: 660 kb/s
#     Stream #0:0(und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p, 640x360 [SAR 1:1 DAR 16:9], 562 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 95 kb/s (default)
#     Metadata:
#       creation_time   : 2016-02-08T02:42:02.000000Z
#       handler_name    : IsoMedia File Produced by Google, 5-11-2011
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> rawvideo (native))
# Press [q] to stop, [?] for help
# Output #0, rawvideo, to 'pipe:':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf58.45.100
#     Stream #0:0(und): Video: rawvideo (RGB[24] / 0x18424752), rgb24, 640x360 [SAR 1:1 DAR 16:9], q=2-31, 5529 kb/s, 1 fps, 1 tbn, 1 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.91.100 rawvideo
# frame=  131 fps=0.0 q=-0.0 Lsize=   88425kB time=00:02:11.00 bitrate=5529.6kbits/s dup=0 drop=2975 speed= 134x
# video:88425kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# ffmpeg version 9c33b2f Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/dvmm-filer2/users/ali/anaconda3/envs/envVatt --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/dvmm-filer3a/users/yulei/data/crosstask/crosstask_videos/videos/0IAFMFVNwZc.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2014-06-24T04:32:27.000000Z
#   Duration: 00:02:34.06, start: 0.000000, bitrate: 703 kb/s
#     Stream #0:0(und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p, 640x360 [SAR 1:1 DAR 16:9], 605 kb/s, 24 fps, 24 tbr, 24 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 95 kb/s (default)
#     Metadata:
#       creation_time   : 2014-06-24T04:32:29.000000Z
#       handler_name    : IsoMedia File Produced by Google, 5-11-2011
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> rawvideo (native))
# Press [q] to stop, [?] for help
# Output #0, rawvideo, to 'pipe:':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf58.45.100
#     Stream #0:0(und): Video: rawvideo (RGB[24] / 0x18424752), rgb24, 640x360 [SAR 1:1 DAR 16:9], q=2-31, 5529 kb/s, 1 fps, 1 tbn, 1 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.91.100 rawvideo
# frame=  156 fps=115 q=-0.0 Lsize=  105300kB time=00:02:36.00 bitrate=5529.6kbits/s dup=0 drop=3540 speed= 115x
# video:105300kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# ffmpeg version 9c33b2f Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/dvmm-filer2/users/ali/anaconda3/envs/envVatt --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/dvmm-filer3a/users/yulei/data/crosstask/crosstask_videos/videos/XX6huDMy4nI.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2020-07-29T12:53:42.000000Z
#   Duration: 00:04:13.33, start: 0.000000, bitrate: 425 kb/s
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 480x360 [SAR 1:1 DAR 4:3], 293 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2020-07-29T12:53:42.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 07/29/2020.
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2020-07-29T12:53:42.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 07/29/2020.
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> rawvideo (native))
# Press [q] to stop, [?] for help
# Output #0, rawvideo, to 'pipe:':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf58.45.100
#     Stream #0:0(und): Video: rawvideo (RGB[24] / 0x18424752), rgb24, 480x360 [SAR 1:1 DAR 4:3], q=2-31, 4147 kb/s, 1 fps, 1 tbn, 1 tbc (default)
#     Metadata:
#       creation_time   : 2020-07-29T12:53:42.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 07/29/2020.
#       encoder         : Lavc58.91.100 rawvideo
# frame=  255 fps=130 q=-0.0 Lsize=  129094kB time=00:04:15.00 bitrate=4147.2kbits/s dup=0 drop=7338 speed= 130x
# video:129094kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# ffmpeg version 9c33b2f Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/dvmm-filer2/users/ali/anaconda3/envs/envVatt --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/dvmm-filer3a/users/yulei/data/crosstask/crosstask_videos/videos/mJ8ejCHwMZ0.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2015-05-24T17:43:00.000000Z
#   Duration: 00:06:13.08, start: 0.000000, bitrate: 481 kb/s
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p, 480x360 [SAR 1:1 DAR 4:3], 352 kb/s, 29.97 fps, 29.97 tbr, 90k tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2015-05-24T17:43:00.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 05/24/2015.
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 125 kb/s (default)
#     Metadata:
#       creation_time   : 2015-05-24T17:43:00.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 05/24/2015.
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> rawvideo (native))
# Press [q] to stop, [?] for help
# Output #0, rawvideo, to 'pipe:':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf58.45.100
#     Stream #0:0(und): Video: rawvideo (RGB[24] / 0x18424752), rgb24, 480x360 [SAR 1:1 DAR 4:3], q=2-31, 4147 kb/s, 1 fps, 1 tbn, 1 tbc (default)
#     Metadata:
#       creation_time   : 2015-05-24T17:43:00.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 05/24/2015.
#       encoder         : Lavc58.91.100 rawvideo
# frame=  375 fps=137 q=-0.0 Lsize=  189844kB time=00:06:15.00 bitrate=4147.2kbits/s dup=0 drop=10806 speed= 137x
# video:189844kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%
